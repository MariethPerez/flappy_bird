# %%
import gym
import numpy as np
import pygame
from gym import spaces
from pygame.locals import *
import matplotlib.pyplot as plt

# Constants for the game
SCREEN_WIDTH = 288
SCREEN_HEIGHT = 512
FPS = 60
BIRD_WIDTH, BIRD_HEIGHT = 34, 24
MONSTER_WIDTH, MONSTER_HEIGHT = 40, 40  # Monster's size

# Define the FlappyBirdWithMonsterEnv Class
class FlappyBirdWithMonsterEnv(gym.Env):
    def __init__(self):
        super(FlappyBirdWithMonsterEnv, self).__init__()

        # Action Space: 0 = Do nothing, 1 = Flap
        self.action_space = spaces.Discrete(2)

        # Observation Space: Screen dimensions (width, height, 3 channels for RGB)
        self.observation_space = spaces.Box(low=0, high=255, shape=(SCREEN_HEIGHT, SCREEN_WIDTH, 3), dtype=np.uint8)

        # Initialize Pygame
        pygame.init()

        # Create the screen object and set the caption
        self.screen = pygame.display.set_mode((SCREEN_WIDTH, SCREEN_HEIGHT))
        pygame.display.set_caption("Flappy Bird with Monster")
        
        # Define game variables
        self.bird = None
        self.bird_x = SCREEN_WIDTH // 4
        self.bird_y = SCREEN_HEIGHT // 2
        self.bird_velocity = 0
        self.gravity = 0.25
        self.lift = -5
        self.pipes = []
        self.pipe_width = 50
        self.pipe_gap = 150
        self.pipe_velocity = 4
        self.score = 0
        self.monster = None  # Initially no monster
        self.monster_x = None
        self.monster_y = None

        self.clock = pygame.time.Clock()

    def reset(self):
        # Reset bird and game state
        self.bird_y = SCREEN_HEIGHT // 2
        self.bird_velocity = 0
        self.pipes = []
        self.score = 0
        self.monster = None  # No monster at the start
        self.monster_x = None
        self.monster_y = None
        self.create_pipe()
        return self.get_state()

    def get_state(self):
        # Returns the current screen as the state
        state = pygame.surfarray.array3d(pygame.display.get_surface())
        # Transpose the state to (height, width, channels)
        state = np.transpose(state, (1, 0, 2))  # Swap width and height axes
        return state

    def create_pipe(self):
        # Position pipes randomly in the middle of the screen with a gap for the bird to pass
        gap_y = np.random.randint(100, SCREEN_HEIGHT - self.pipe_gap - 100)  # Random gap for bird to pass
        pipe_x = np.random.randint(SCREEN_WIDTH // 2, SCREEN_WIDTH)  # Random horizontal position for pipes within the screen
        top_rect = pygame.Rect(pipe_x, 0, self.pipe_width, gap_y)  # Top pipe starts at the top
        bottom_rect = pygame.Rect(pipe_x, gap_y + self.pipe_gap, self.pipe_width, SCREEN_HEIGHT - gap_y - self.pipe_gap)  # Bottom pipe
        self.pipes.append((top_rect, bottom_rect))

        # Debugging: Print the pipe positions
        print(f"Created pipe at x={pipe_x}, top_rect.y={gap_y}, bottom_rect.y={gap_y + self.pipe_gap}")

    def step(self, action):
        # Handle events
        for event in pygame.event.get():
            if event.type == QUIT:
                pygame.quit()
                quit()

        # Action: 0 = Do nothing, 1 = Flap
        if action == 1:
            self.bird_velocity = self.lift

        # Update bird's velocity and position
        self.bird_velocity += self.gravity
        self.bird_y += self.bird_velocity

        # Check for collisions with the ceiling and ground
        if self.bird_y < 0 or self.bird_y > SCREEN_HEIGHT:
            return self.get_state(), -1, True, {}

        # Move pipes and check for collisions
        reward = 0
        for top_rect, bottom_rect in self.pipes:
            top_rect.x -= self.pipe_velocity
            bottom_rect.x -= self.pipe_velocity

            # Debugging: Print pipe x position while moving
            print(f"Moving pipe at x={top_rect.x}, bottom_rect.x={bottom_rect.x}")

            if top_rect.right < 0:
                self.pipes.remove((top_rect, bottom_rect))
                self.create_pipe()
                self.score += 1
                reward = 1  # Reward for passing a pipe

            # Check for collision with pipes
            if top_rect.colliderect(pygame.Rect(self.bird_x, self.bird_y, BIRD_WIDTH, BIRD_HEIGHT)) or bottom_rect.colliderect(pygame.Rect(self.bird_x, self.bird_y, BIRD_WIDTH, BIRD_HEIGHT)):
                return self.get_state(), -1, True, {}

        # If the bird has failed, spawn the monster
        if self.monster is None:
            self.monster_x = SCREEN_WIDTH // 2
            self.monster_y = np.random.randint(0, SCREEN_HEIGHT)
            self.monster = pygame.Rect(self.monster_x, self.monster_y, MONSTER_WIDTH, MONSTER_HEIGHT)

        # Move the monster toward the bird
        if self.monster is not None:
            self.monster.x -= 2  # Monster moves towards the bird
            if self.monster.x < self.bird_x + BIRD_WIDTH and self.monster.colliderect(pygame.Rect(self.bird_x, self.bird_y, BIRD_WIDTH, BIRD_HEIGHT)):
                return self.get_state(), -10, True, {"message": "Monster caught the bird!"}

        # Draw everything
        self.screen.fill((0, 0, 0))  # Black background
        pygame.draw.rect(self.screen, (255, 0, 0), (self.bird_x, self.bird_y, BIRD_WIDTH, BIRD_HEIGHT))  # Bird

        # Drawing the pipes
        for top_rect, bottom_rect in self.pipes:
            pygame.draw.rect(self.screen, (0, 255, 0), top_rect)  # Top pipe
            pygame.draw.rect(self.screen, (0, 255, 0), bottom_rect)  # Bottom pipe

        # Draw the monster if it exists
        if self.monster is not None:
            pygame.draw.rect(self.screen, (0, 0, 255), self.monster)  # Monster

        pygame.display.update()
        self.clock.tick(FPS)

        return self.get_state(), reward, False, {}

    def render(self):
        pygame.display.flip()

    def close(self):
        pygame.quit()

# %%
# Create the environment
env = FlappyBirdWithMonsterEnv()

# Reset the environment to start a new game
state = env.reset()

# Run random actions to see the environment in action
for _ in range(1000):
    action = env.action_space.sample()  # Random action: flap or do nothing
    state, reward, done, info = env.step(action)  # Apply the action to the environment

    # Display the environment after action
    if _ % 50 == 0:  # Display every 50 steps
        plt.imshow(state)
        plt.title(f'Episode {_}, Reward: {reward}')
        plt.show()

    # Print debugging info every 50 steps to check pipe creation and movement
    if _ % 50 == 0:
        print(f"Debugging: Episode {_}")
    
    if done:
        print(f"Game Over! Info: {info}")
        break

env.close()
# Out:
# Created pipe at x=276, top_rect.y=182, bottom_rect.y=332
# Moving pipe at x=272, bottom_rect.x=272
# Debugging: Episode 0
# Moving pipe at x=268, bottom_rect.x=268
# Moving pipe at x=264, bottom_rect.x=264
# Moving pipe at x=260, bottom_rect.x=260
# Moving pipe at x=256, bottom_rect.x=256
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Game Over! Info: {}

# %% [markdown]
# ### Flappy Bird with Monster Environment
# #### This custom Flappy Bird with Monster environment is built using reinforcement learning principles, where the agent (the bird) tries to navigate through obstacles (pipes) while avoiding getting caught by a monster.
#
# #### Key Features of the Environment:
# #### Bird (Red Square): The bird is controlled by the agent. The bird’s movement is influenced by gravity and the flap action. The flap moves the bird upwards, and gravity pulls it downward.
#
# #### Monster (Blue Square): After the bird fails (e.g., by colliding with pipes or the ground), a monster spawns at a random position and moves toward the bird. If the monster catches the bird, the game ends with a penalty.
#
# #### Pipes (Green Rectangles): Pipes are randomly generated with a gap for the bird to fly through. The pipes start from the right side of the screen and move leftward. The goal is to navigate through the gap without hitting the pipes or the ground.
#
# #### Game Flow:
# #### Start: The game begins with the bird positioned in the middle of the screen.
#
# #### Pipes Generation: The pipes are generated randomly along the screen, and the bird must navigate through the gap.
#
# #### Monster Activation: If the bird fails, a monster appears and moves toward the bird. If the bird is caught by the monster, the game ends.
#
# #### Reward System: The agent receives rewards for passing through the pipes and penalties for collisions with the pipes, the ground, or being caught by the monster.
#
# #### Observations and Actions:
# #### Observation: The environment returns an image of the screen, which includes the bird, pipes, and monster. This image serves as the state that the agent can use to make decisions.
#
# #### Actions: The agent can take two actions:
#
# #### 0: Do nothing (gravity affects the bird).
#
# #### 1: Flap (move the bird upward).
#
# #### Screenshot Description:
# #### The provided screenshot shows:
#
# #### The bird (red square) positioned near the bottom of the screen.
#
# #### The monster (blue square) is in the lower-middle area of the screen, and it moves towards the bird.
#
# #### Green pipes are positioned across the screen, with a gap for the bird to fly through.
#
# #### This environment serves as a great starting point for testing reinforcement learning algorithms, particularly when trying to train an agent to make decisions based on visual input (image-based state representation). The added monster introduces an additional layer of complexity, making the environment more dynamic and challenging.

# %% [markdown]
# ### defining the deep Q-Network Algorithm

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

class QNetwork(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 128)  # First hidden layer
        self.fc2 = nn.Linear(128, 128)  # Second hidden layer
        self.fc3 = nn.Linear(128, output_dim)  # Output layer (Q-values for all actions)

    def forward(self, state):
        x = F.relu(self.fc1(state))  # Apply ReLU activation
        x = F.relu(self.fc2(x))  # Apply ReLU activation
        return self.fc3(x)  # Return Q-values for each action

# %%
import random
import numpy as np
from collections import deque

class DQNAgent:
    def __init__(self, state_size, action_size, gamma=0.99, epsilon=1.0, epsilon_decay=0.995, epsilon_min=0.1, batch_size=64, memory_size=10000, learning_rate=0.001):
        self.state_size = state_size
        self.action_size = action_size
        self.gamma = gamma  # Discount factor
        self.epsilon = epsilon  # Exploration factor
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.batch_size = batch_size
        self.memory = deque(maxlen=memory_size)  # Experience replay memory
        self.learning_rate = learning_rate

        # Create the Q-network and target network
        self.q_network = QNetwork(state_size, action_size)
        self.target_network = QNetwork(state_size, action_size)
        self.target_network.load_state_dict(self.q_network.state_dict())  # Initialize target network with the Q-network weights

        # Optimizer
        self.optimizer = optim.Adam(self.q_network.parameters(), lr=self.learning_rate)

    def remember(self, state, action, reward, next_state, done):
        # Store the experience in memory
        self.memory.append((state, action, reward, next_state, done))

    def act(self, state):
        if random.random() <= self.epsilon:
            return random.randrange(self.action_size)  # Explore: random action

        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0).view(1, -1)  # Flatten state
        q_values = self.q_network(state_tensor)  # Get Q-values for all actions
        return torch.argmax(q_values).item()  # Exploit: action with highest Q-value

    def replay(self):
        if len(self.memory) < self.batch_size:
            return  # Not enough experience in memory to sample

        # Sample a batch of experiences from memory
        batch = random.sample(self.memory, self.batch_size)
        states, actions, rewards, next_states, dones = zip(*batch)

        # Convert to tensors and flatten the states
        states = torch.tensor(states, dtype=torch.float32).view(self.batch_size, -1)  # Flatten states
        actions = torch.tensor(actions, dtype=torch.long)
        rewards = torch.tensor(rewards, dtype=torch.float32)
        next_states = torch.tensor(next_states, dtype=torch.float32).view(self.batch_size, -1)  # Flatten next states
        dones = torch.tensor(dones, dtype=torch.float32)

        # Get the current Q-values from the Q-network
        q_values = self.q_network(states)
        q_values = q_values.gather(1, actions.unsqueeze(1)).squeeze(1)  # Q-value for the chosen action

        # Get the target Q-values from the target network
        target_q_values = self.target_network(next_states)
        target_q_values = target_q_values.max(1)[0]  # Maximum Q-value for the next state (Bellman equation)

        # Update the target Q-value
        targets = rewards + (self.gamma * target_q_values * (1 - dones))  # Bellman equation

        # Loss (Mean Squared Error between predicted Q-values and target Q-values)
        loss = F.mse_loss(q_values, targets)

        # Optimize the Q-network
        self.optimizer.zero_grad()
        loss.backward()
        self.optimizer.step()

        # Update epsilon for exploration
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

    def update_target_network(self):
        # Periodically copy Q-network weights to the target network
        self.target_network.load_state_dict(self.q_network.state_dict())

# %%
def train_dqn(env, agent, episodes=100, max_timesteps=500):
    for episode in range(episodes):  # Ensure episodes are set to 100
        state = env.reset()
        state = np.reshape(state, [1, agent.state_size])  # Reshape state
        total_reward = 0

        for t in range(max_timesteps):
            action = agent.act(state)  # Choose action using epsilon-greedy strategy
            next_state, reward, done, _ = env.step(action)
            next_state = np.reshape(next_state, [1, agent.state_size])  # Reshape next state

            agent.remember(state, action, reward, next_state, done)  # Store experience
            state = next_state
            total_reward += reward

            if len(agent.memory) > agent.batch_size:  # Train only if enough samples are collected
                agent.replay()  # Train agent on experiences in memory

            if done:
                break

        if episode % 10 == 0:  # Update target network every 10 episodes
            agent.update_target_network()

        print(f"Episode {episode + 1}/{episodes}, Total Reward: {total_reward}, Epsilon: {agent.epsilon}")

    return agent

# %%
def test_agent(env, agent, episodes=10):
    # Set epsilon to 0 for testing (no exploration, always exploit learned policy)
    agent.epsilon = 0.0
    
    test_rewards = []  # List to store rewards for each test episode
    
    for episode in range(episodes):
        state = env.reset()
        state = np.reshape(state, [1, agent.state_size])  # Reshape state
        total_reward = 0

        for t in range(500):  # Maximum number of timesteps
            action = agent.act(state)  # Choose action using the trained Q-network
            next_state, reward, done, _ = env.step(action)
            next_state = np.reshape(next_state, [1, agent.state_size])  # Reshape next state

            state = next_state
            total_reward += reward

            if done:
                break

        # Store the total reward for the current episode
        test_rewards.append(total_reward)
        
        print(f"Test Episode {episode + 1}/{episodes}, Total Reward: {total_reward}")

    return test_rewards  # Return the collected rewards for plotting

# %%
# Set up the environment
env = FlappyBirdWithMonsterEnv()  # Your custom Flappy Bird with Monster environment

# Initialize the DQN agent
state_size = SCREEN_HEIGHT * SCREEN_WIDTH * 3  # Flattening the state to match image dimensions
action_size = env.action_space.n  # Number of actions
agent = DQNAgent(state_size, action_size)

# Train the agent
trained_agent = train_dqn(env, agent)

# Test the trained agent
test_agent(env, trained_agent)
# Out:
# Created pipe at x=192, top_rect.y=108, bottom_rect.y=258
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Episode 1/100, Total Reward: -10, Epsilon: 1.0
# Created pipe at x=171, top_rect.y=113, bottom_rect.y=263
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Moving pipe at x=99, bottom_rect.x=99
# Moving pipe at x=95, bottom_rect.x=95
# Moving pipe at x=91, bottom_rect.x=91
# Moving pipe at x=87, bottom_rect.x=87
# Moving pipe at x=83, bottom_rect.x=83
# Moving pipe at x=79, bottom_rect.x=79
# Moving pipe at x=75, bottom_rect.x=75
# Moving pipe at x=71, bottom_rect.x=71
# Moving pipe at x=67, bottom_rect.x=67
# Moving pipe at x=63, bottom_rect.x=63
# Moving pipe at x=59, bottom_rect.x=59
# Moving pipe at x=55, bottom_rect.x=55
# Moving pipe at x=51, bottom_rect.x=51
# Moving pipe at x=47, bottom_rect.x=47
# Moving pipe at x=43, bottom_rect.x=43
# Episode 2/100, Total Reward: -1, Epsilon: 1.0
# Created pipe at x=221, top_rect.y=194, bottom_rect.y=344
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# C:\Users\PC\AppData\Local\Temp\ipykernel_8240\343911444.py:46: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   states = torch.tensor(states, dtype=torch.float32).view(self.batch_size, -1)  # Flatten states
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 3/100, Total Reward: -1, Epsilon: 0.8911090557802088
# Created pipe at x=229, top_rect.y=131, bottom_rect.y=281
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Episode 4/100, Total Reward: -10, Epsilon: 0.8061065909263957
# Created pipe at x=214, top_rect.y=142, bottom_rect.y=292
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 5/100, Total Reward: -1, Epsilon: 0.7005493475733617
# Created pipe at x=174, top_rect.y=184, bottom_rect.y=334
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 6/100, Total Reward: -1, Epsilon: 0.6401093727576664
# Created pipe at x=150, top_rect.y=205, bottom_rect.y=355
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 7/100, Total Reward: -1, Epsilon: 0.6027415843082742
# Created pipe at x=216, top_rect.y=167, bottom_rect.y=317
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 8/100, Total Reward: -1, Epsilon: 0.5238143793828016
# Created pipe at x=204, top_rect.y=175, bottom_rect.y=325
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 9/100, Total Reward: -1, Epsilon: 0.46211964903917074
# Created pipe at x=279, top_rect.y=209, bottom_rect.y=359
# Moving pipe at x=275, bottom_rect.x=275
# Moving pipe at x=271, bottom_rect.x=271
# Moving pipe at x=267, bottom_rect.x=267
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 10/100, Total Reward: -1, Epsilon: 0.3706551064126331
# Created pipe at x=279, top_rect.y=225, bottom_rect.y=375
# Moving pipe at x=275, bottom_rect.x=275
# Moving pipe at x=271, bottom_rect.x=271
# Moving pipe at x=267, bottom_rect.x=267
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 11/100, Total Reward: -1, Epsilon: 0.29729358661854943
# Created pipe at x=178, top_rect.y=248, bottom_rect.y=398
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 12/100, Total Reward: -1, Epsilon: 0.2702863258025825
# Created pipe at x=226, top_rect.y=195, bottom_rect.y=345
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Episode 13/100, Total Reward: -10, Epsilon: 0.24450384299593592
# Created pipe at x=282, top_rect.y=126, bottom_rect.y=276
# Moving pipe at x=278, bottom_rect.x=278
# Moving pipe at x=274, bottom_rect.x=274
# Moving pipe at x=270, bottom_rect.x=270
# Moving pipe at x=266, bottom_rect.x=266
# Moving pipe at x=262, bottom_rect.x=262
# Moving pipe at x=258, bottom_rect.x=258
# Moving pipe at x=254, bottom_rect.x=254
# Moving pipe at x=250, bottom_rect.x=250
# Moving pipe at x=246, bottom_rect.x=246
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 14/100, Total Reward: -1, Epsilon: 0.19513012515638165
# Created pipe at x=163, top_rect.y=169, bottom_rect.y=319
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Moving pipe at x=99, bottom_rect.x=99
# Moving pipe at x=95, bottom_rect.x=95
# Moving pipe at x=91, bottom_rect.x=91
# Moving pipe at x=87, bottom_rect.x=87
# Moving pipe at x=83, bottom_rect.x=83
# Moving pipe at x=79, bottom_rect.x=79
# Moving pipe at x=75, bottom_rect.x=75
# Moving pipe at x=71, bottom_rect.x=71
# Moving pipe at x=67, bottom_rect.x=67
# Moving pipe at x=63, bottom_rect.x=63
# Moving pipe at x=59, bottom_rect.x=59
# Moving pipe at x=55, bottom_rect.x=55
# Moving pipe at x=51, bottom_rect.x=51
# Moving pipe at x=47, bottom_rect.x=47
# Moving pipe at x=43, bottom_rect.x=43
# Moving pipe at x=39, bottom_rect.x=39
# Moving pipe at x=35, bottom_rect.x=35
# Moving pipe at x=31, bottom_rect.x=31
# Moving pipe at x=27, bottom_rect.x=27
# Moving pipe at x=23, bottom_rect.x=23
# Episode 15/100, Total Reward: -1, Epsilon: 0.16373146555890544
# Created pipe at x=209, top_rect.y=209, bottom_rect.y=359
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 16/100, Total Reward: -1, Epsilon: 0.14372497725712216
# Created pipe at x=184, top_rect.y=122, bottom_rect.y=272
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Moving pipe at x=76, bottom_rect.x=76
# Moving pipe at x=72, bottom_rect.x=72
# Moving pipe at x=68, bottom_rect.x=68
# Moving pipe at x=64, bottom_rect.x=64
# Episode 17/100, Total Reward: -1, Epsilon: 0.12365869841532712
# Created pipe at x=196, top_rect.y=200, bottom_rect.y=350
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 18/100, Total Reward: -1, Epsilon: 0.11019338598389174
# Created pipe at x=228, top_rect.y=119, bottom_rect.y=269
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Episode 19/100, Total Reward: -10, Epsilon: 0.0996820918179746
# Created pipe at x=155, top_rect.y=235, bottom_rect.y=385
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 20/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=156, top_rect.y=210, bottom_rect.y=360
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 21/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=286, top_rect.y=221, bottom_rect.y=371
# Moving pipe at x=282, bottom_rect.x=282
# Moving pipe at x=278, bottom_rect.x=278
# Moving pipe at x=274, bottom_rect.x=274
# Moving pipe at x=270, bottom_rect.x=270
# Moving pipe at x=266, bottom_rect.x=266
# Moving pipe at x=262, bottom_rect.x=262
# Moving pipe at x=258, bottom_rect.x=258
# Moving pipe at x=254, bottom_rect.x=254
# Moving pipe at x=250, bottom_rect.x=250
# Moving pipe at x=246, bottom_rect.x=246
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 22/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=249, top_rect.y=224, bottom_rect.y=374
# Moving pipe at x=245, bottom_rect.x=245
# Moving pipe at x=241, bottom_rect.x=241
# Moving pipe at x=237, bottom_rect.x=237
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Episode 23/100, Total Reward: -10, Epsilon: 0.0996820918179746
# Created pipe at x=161, top_rect.y=116, bottom_rect.y=266
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Moving pipe at x=77, bottom_rect.x=77
# Moving pipe at x=73, bottom_rect.x=73
# Moving pipe at x=69, bottom_rect.x=69
# Moving pipe at x=65, bottom_rect.x=65
# Moving pipe at x=61, bottom_rect.x=61
# Moving pipe at x=57, bottom_rect.x=57
# Moving pipe at x=53, bottom_rect.x=53
# Moving pipe at x=49, bottom_rect.x=49
# Moving pipe at x=45, bottom_rect.x=45
# Moving pipe at x=41, bottom_rect.x=41
# Moving pipe at x=37, bottom_rect.x=37
# Moving pipe at x=33, bottom_rect.x=33
# Episode 24/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=207, top_rect.y=165, bottom_rect.y=315
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 25/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=165, top_rect.y=153, bottom_rect.y=303
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Moving pipe at x=77, bottom_rect.x=77
# Moving pipe at x=73, bottom_rect.x=73
# Episode 26/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=178, top_rect.y=176, bottom_rect.y=326
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Moving pipe at x=98, bottom_rect.x=98
# Moving pipe at x=94, bottom_rect.x=94
# Moving pipe at x=90, bottom_rect.x=90
# Episode 27/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=173, top_rect.y=188, bottom_rect.y=338
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Episode 28/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=264, top_rect.y=208, bottom_rect.y=358
# Moving pipe at x=260, bottom_rect.x=260
# Moving pipe at x=256, bottom_rect.x=256
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 29/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=248, top_rect.y=215, bottom_rect.y=365
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 30/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=153, top_rect.y=242, bottom_rect.y=392
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 31/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=196, top_rect.y=235, bottom_rect.y=385
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 32/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=192, top_rect.y=247, bottom_rect.y=397
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 33/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=256, top_rect.y=252, bottom_rect.y=402
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 34/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=276, top_rect.y=191, bottom_rect.y=341
# Moving pipe at x=272, bottom_rect.x=272
# Moving pipe at x=268, bottom_rect.x=268
# Moving pipe at x=264, bottom_rect.x=264
# Moving pipe at x=260, bottom_rect.x=260
# Moving pipe at x=256, bottom_rect.x=256
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 35/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=227, top_rect.y=227, bottom_rect.y=377
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 36/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=188, top_rect.y=169, bottom_rect.y=319
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 37/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=172, top_rect.y=182, bottom_rect.y=332
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Episode 38/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=165, top_rect.y=159, bottom_rect.y=309
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Moving pipe at x=77, bottom_rect.x=77
# Moving pipe at x=73, bottom_rect.x=73
# Moving pipe at x=69, bottom_rect.x=69
# Episode 39/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=233, top_rect.y=139, bottom_rect.y=289
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Episode 40/100, Total Reward: -10, Epsilon: 0.0996820918179746
# Created pipe at x=218, top_rect.y=184, bottom_rect.y=334
# ...
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 97/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=209, top_rect.y=211, bottom_rect.y=361
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 98/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=242, top_rect.y=137, bottom_rect.y=287
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 99/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=220, top_rect.y=120, bottom_rect.y=270
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Episode 100/100, Total Reward: -10, Epsilon: 0.0996820918179746
# Created pipe at x=185, top_rect.y=160, bottom_rect.y=310
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Test Episode 1/10, Total Reward: -10
# Created pipe at x=244, top_rect.y=203, bottom_rect.y=353
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Test Episode 2/10, Total Reward: -1
# Created pipe at x=146, top_rect.y=185, bottom_rect.y=335
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Moving pipe at x=98, bottom_rect.x=98
# Moving pipe at x=94, bottom_rect.x=94
# Moving pipe at x=90, bottom_rect.x=90
# Moving pipe at x=86, bottom_rect.x=86
# Moving pipe at x=82, bottom_rect.x=82
# Test Episode 3/10, Total Reward: -1
# Created pipe at x=169, top_rect.y=142, bottom_rect.y=292
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Test Episode 4/10, Total Reward: -1
# Created pipe at x=236, top_rect.y=195, bottom_rect.y=345
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Test Episode 5/10, Total Reward: -1
# Created pipe at x=240, top_rect.y=149, bottom_rect.y=299
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Test Episode 6/10, Total Reward: -1
# Created pipe at x=249, top_rect.y=193, bottom_rect.y=343
# Moving pipe at x=245, bottom_rect.x=245
# Moving pipe at x=241, bottom_rect.x=241
# Moving pipe at x=237, bottom_rect.x=237
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Test Episode 7/10, Total Reward: -10
# Created pipe at x=183, top_rect.y=132, bottom_rect.y=282
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Moving pipe at x=99, bottom_rect.x=99
# Moving pipe at x=95, bottom_rect.x=95
# Moving pipe at x=91, bottom_rect.x=91
# Moving pipe at x=87, bottom_rect.x=87
# Moving pipe at x=83, bottom_rect.x=83
# Moving pipe at x=79, bottom_rect.x=79
# Moving pipe at x=75, bottom_rect.x=75
# Moving pipe at x=71, bottom_rect.x=71
# Moving pipe at x=67, bottom_rect.x=67
# Moving pipe at x=63, bottom_rect.x=63
# Moving pipe at x=59, bottom_rect.x=59
# Moving pipe at x=55, bottom_rect.x=55
# Moving pipe at x=51, bottom_rect.x=51
# Test Episode 8/10, Total Reward: -10
# Created pipe at x=162, top_rect.y=149, bottom_rect.y=299
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Moving pipe at x=98, bottom_rect.x=98
# Moving pipe at x=94, bottom_rect.x=94
# Moving pipe at x=90, bottom_rect.x=90
# Moving pipe at x=86, bottom_rect.x=86
# Moving pipe at x=82, bottom_rect.x=82
# Moving pipe at x=78, bottom_rect.x=78
# Moving pipe at x=74, bottom_rect.x=74
# Moving pipe at x=70, bottom_rect.x=70
# Moving pipe at x=66, bottom_rect.x=66
# Moving pipe at x=62, bottom_rect.x=62
# Moving pipe at x=58, bottom_rect.x=58
# Moving pipe at x=54, bottom_rect.x=54
# Test Episode 9/10, Total Reward: -1
# Created pipe at x=222, top_rect.y=146, bottom_rect.y=296
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Test Episode 10/10, Total Reward: -1
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import matplotlib.pyplot as plt

# Manually input the rewards from the console output
baseline_test_rewards = [-10, -1, -1, -1, -1, -1, -10, -10, -1, -1] 

# Plotting the learning curve for baseline rewards
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(baseline_test_rewards) + 1), baseline_test_rewards, label='Baseline Test Rewards', color='blue')
plt.xlabel('Test Episode')
plt.ylabel('Total Reward')
plt.title('Baseline Learning Curve (Total Reward per Test Episode)')
plt.legend()
plt.show()

# %%
# Test the trained agent
test_agent(env, trained_agent)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Test the trained agent
# ----> 2 test_agent(env, trained_agent)
#
# NameError: name 'trained_agent' is not defined

# %% [markdown]
# Baseline Hyperparameters:
# Gamma (Discount Factor): 0.99
#
# Epsilon (Exploration Rate): 1.0 (decays to 0.1 over time)
#
# Batch Size: 64
#
# Memory Size: 10000
#
# Learning Rate: 0.001
#
# Max Timesteps per Episode: 500
#
# Target Network Update Frequency: Every 10 episodes
#
# Epsilon Decay Rate: 0.995
#
# Minimum Epsilon: 0.1

# %%
# Set up the environment (No need to initialize again, as it’s already initialized in the baseline code)
env = FlappyBirdWithMonsterEnv()  # Your custom Flappy Bird with Monster environment

# Define state and action sizes based on the environment
state_size = SCREEN_HEIGHT * SCREEN_WIDTH * 3  # Flattening the state to match image dimensions
action_size = env.action_space.n  # Number of actions

# -----------------------------
# Experiment 1: Epsilon Decay and Learning Rate Adjustment
# -----------------------------

# Initialize the DQN agent (Experiment 1)
experiment_1_agent = DQNAgent(
    state_size=state_size,
    action_size=action_size,
    gamma=0.99,                      # Same as baseline
    epsilon=1.0,                     # Same as baseline
    epsilon_decay=0.99,              # Faster decay
    epsilon_min=0.1,                 # Same as baseline
    batch_size=64,                   # Same as baseline
    memory_size=10000,               # Same as baseline
    learning_rate=0.0005             # Lower learning rate
)

# Train the agent with Experiment 1 hyperparameters
trained_agent_exp_1 = train_dqn(env, experiment_1_agent)

# Test the trained agent from Experiment 1
test_agent(env, trained_agent_exp_1)
# Out:
# Created pipe at x=237, top_rect.y=176, bottom_rect.y=326
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 1/100, Total Reward: -1, Epsilon: 1.0
# Created pipe at x=272, top_rect.y=207, bottom_rect.y=357
# Moving pipe at x=268, bottom_rect.x=268
# Moving pipe at x=264, bottom_rect.x=264
# Moving pipe at x=260, bottom_rect.x=260
# Moving pipe at x=256, bottom_rect.x=256
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Episode 2/100, Total Reward: -10, Epsilon: 1.0
# Created pipe at x=169, top_rect.y=162, bottom_rect.y=312
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# C:\Users\PC\AppData\Local\Temp\ipykernel_17840\343911444.py:46: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_new.cpp:257.)
#   states = torch.tensor(states, dtype=torch.float32).view(self.batch_size, -1)  # Flatten states
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Episode 3/100, Total Reward: -1, Epsilon: 0.8953382542587163
# Created pipe at x=180, top_rect.y=230, bottom_rect.y=380
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 4/100, Total Reward: -1, Epsilon: 0.7397003733882802
# Created pipe at x=242, top_rect.y=239, bottom_rect.y=389
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 5/100, Total Reward: -1, Epsilon: 0.5203405226503064
# Created pipe at x=165, top_rect.y=117, bottom_rect.y=267
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Moving pipe at x=77, bottom_rect.x=77
# Moving pipe at x=73, bottom_rect.x=73
# Moving pipe at x=69, bottom_rect.x=69
# Moving pipe at x=65, bottom_rect.x=65
# Moving pipe at x=61, bottom_rect.x=61
# Moving pipe at x=57, bottom_rect.x=57
# Moving pipe at x=53, bottom_rect.x=53
# Moving pipe at x=49, bottom_rect.x=49
# Moving pipe at x=45, bottom_rect.x=45
# Moving pipe at x=41, bottom_rect.x=41
# Episode 6/100, Total Reward: -1, Epsilon: 0.38104711810454983
# Created pipe at x=206, top_rect.y=239, bottom_rect.y=389
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 7/100, Total Reward: -1, Epsilon: 0.29342272152521587
# Created pipe at x=189, top_rect.y=128, bottom_rect.y=278
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Moving pipe at x=77, bottom_rect.x=77
# Episode 8/100, Total Reward: -1, Epsilon: 0.22145178723886094
# Created pipe at x=193, top_rect.y=110, bottom_rect.y=260
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Moving pipe at x=77, bottom_rect.x=77
# Moving pipe at x=73, bottom_rect.x=73
# Moving pipe at x=69, bottom_rect.x=69
# Moving pipe at x=65, bottom_rect.x=65
# Moving pipe at x=61, bottom_rect.x=61
# Episode 9/100, Total Reward: -1, Epsilon: 0.15894270919978754
# Created pipe at x=184, top_rect.y=193, bottom_rect.y=343
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 10/100, Total Reward: -1, Epsilon: 0.13000034453500542
# Created pipe at x=284, top_rect.y=130, bottom_rect.y=280
# Moving pipe at x=280, bottom_rect.x=280
# Moving pipe at x=276, bottom_rect.x=276
# Moving pipe at x=272, bottom_rect.x=272
# Moving pipe at x=268, bottom_rect.x=268
# Moving pipe at x=264, bottom_rect.x=264
# Moving pipe at x=260, bottom_rect.x=260
# Moving pipe at x=256, bottom_rect.x=256
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Episode 11/100, Total Reward: -10, Epsilon: 0.10632818368521123
# Created pipe at x=236, top_rect.y=107, bottom_rect.y=257
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Episode 12/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=267, top_rect.y=158, bottom_rect.y=308
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Episode 13/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=218, top_rect.y=109, bottom_rect.y=259
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Episode 14/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=206, top_rect.y=194, bottom_rect.y=344
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 15/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=144, top_rect.y=228, bottom_rect.y=378
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 16/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=275, top_rect.y=251, bottom_rect.y=401
# Moving pipe at x=271, bottom_rect.x=271
# Moving pipe at x=267, bottom_rect.x=267
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 17/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=160, top_rect.y=143, bottom_rect.y=293
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Episode 18/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=263, top_rect.y=248, bottom_rect.y=398
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Episode 19/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=229, top_rect.y=180, bottom_rect.y=330
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Episode 20/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=220, top_rect.y=164, bottom_rect.y=314
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Episode 21/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=208, top_rect.y=206, bottom_rect.y=356
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 22/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=165, top_rect.y=206, bottom_rect.y=356
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 23/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=286, top_rect.y=142, bottom_rect.y=292
# Moving pipe at x=282, bottom_rect.x=282
# Moving pipe at x=278, bottom_rect.x=278
# Moving pipe at x=274, bottom_rect.x=274
# Moving pipe at x=270, bottom_rect.x=270
# Moving pipe at x=266, bottom_rect.x=266
# Moving pipe at x=262, bottom_rect.x=262
# Moving pipe at x=258, bottom_rect.x=258
# Moving pipe at x=254, bottom_rect.x=254
# Moving pipe at x=250, bottom_rect.x=250
# Moving pipe at x=246, bottom_rect.x=246
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 24/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=258, top_rect.y=115, bottom_rect.y=265
# Moving pipe at x=254, bottom_rect.x=254
# Moving pipe at x=250, bottom_rect.x=250
# Moving pipe at x=246, bottom_rect.x=246
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 25/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=146, top_rect.y=179, bottom_rect.y=329
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Moving pipe at x=98, bottom_rect.x=98
# Moving pipe at x=94, bottom_rect.x=94
# Moving pipe at x=90, bottom_rect.x=90
# Moving pipe at x=86, bottom_rect.x=86
# Moving pipe at x=82, bottom_rect.x=82
# Moving pipe at x=78, bottom_rect.x=78
# Episode 26/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=258, top_rect.y=147, bottom_rect.y=297
# Moving pipe at x=254, bottom_rect.x=254
# Moving pipe at x=250, bottom_rect.x=250
# Moving pipe at x=246, bottom_rect.x=246
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Episode 27/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=198, top_rect.y=241, bottom_rect.y=391
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 28/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=232, top_rect.y=222, bottom_rect.y=372
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Episode 29/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=152, top_rect.y=151, bottom_rect.y=301
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Moving pipe at x=76, bottom_rect.x=76
# Moving pipe at x=72, bottom_rect.x=72
# Moving pipe at x=68, bottom_rect.x=68
# Moving pipe at x=64, bottom_rect.x=64
# Moving pipe at x=60, bottom_rect.x=60
# Moving pipe at x=56, bottom_rect.x=56
# Moving pipe at x=52, bottom_rect.x=52
# Moving pipe at x=48, bottom_rect.x=48
# Moving pipe at x=44, bottom_rect.x=44
# Moving pipe at x=40, bottom_rect.x=40
# Moving pipe at x=36, bottom_rect.x=36
# Moving pipe at x=32, bottom_rect.x=32
# Moving pipe at x=28, bottom_rect.x=28
# Moving pipe at x=24, bottom_rect.x=24
# Moving pipe at x=20, bottom_rect.x=20
# Moving pipe at x=16, bottom_rect.x=16
# Moving pipe at x=12, bottom_rect.x=12
# Moving pipe at x=8, bottom_rect.x=8
# Moving pipe at x=4, bottom_rect.x=4
# Moving pipe at x=0, bottom_rect.x=0
# Moving pipe at x=-4, bottom_rect.x=-4
# Moving pipe at x=-8, bottom_rect.x=-8
# Moving pipe at x=-12, bottom_rect.x=-12
# Moving pipe at x=-16, bottom_rect.x=-16
# Moving pipe at x=-20, bottom_rect.x=-20
# Moving pipe at x=-24, bottom_rect.x=-24
# Moving pipe at x=-28, bottom_rect.x=-28
# Moving pipe at x=-32, bottom_rect.x=-32
# Moving pipe at x=-36, bottom_rect.x=-36
# Moving pipe at x=-40, bottom_rect.x=-40
# Moving pipe at x=-44, bottom_rect.x=-44
# Moving pipe at x=-48, bottom_rect.x=-48
# Moving pipe at x=-52, bottom_rect.x=-52
# Created pipe at x=235, top_rect.y=230, bottom_rect.y=380
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Episode 30/100, Total Reward: 0, Epsilon: 0.09910481551887473
# Created pipe at x=265, top_rect.y=140, bottom_rect.y=290
# Moving pipe at x=261, bottom_rect.x=261
# Moving pipe at x=257, bottom_rect.x=257
# Moving pipe at x=253, bottom_rect.x=253
# Moving pipe at x=249, bottom_rect.x=249
# Moving pipe at x=245, bottom_rect.x=245
# Moving pipe at x=241, bottom_rect.x=241
# Moving pipe at x=237, bottom_rect.x=237
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 31/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=277, top_rect.y=155, bottom_rect.y=305
# Moving pipe at x=273, bottom_rect.x=273
# Moving pipe at x=269, bottom_rect.x=269
# Moving pipe at x=265, bottom_rect.x=265
# Moving pipe at x=261, bottom_rect.x=261
# Moving pipe at x=257, bottom_rect.x=257
# Moving pipe at x=253, bottom_rect.x=253
# Moving pipe at x=249, bottom_rect.x=249
# Moving pipe at x=245, bottom_rect.x=245
# Moving pipe at x=241, bottom_rect.x=241
# Moving pipe at x=237, bottom_rect.x=237
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Episode 32/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=172, top_rect.y=216, bottom_rect.y=366
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 33/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=151, top_rect.y=146, bottom_rect.y=296
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Moving pipe at x=99, bottom_rect.x=99
# Moving pipe at x=95, bottom_rect.x=95
# Moving pipe at x=91, bottom_rect.x=91
# Moving pipe at x=87, bottom_rect.x=87
# Moving pipe at x=83, bottom_rect.x=83
# Moving pipe at x=79, bottom_rect.x=79
# Moving pipe at x=75, bottom_rect.x=75
# Moving pipe at x=71, bottom_rect.x=71
# Moving pipe at x=67, bottom_rect.x=67
# Moving pipe at x=63, bottom_rect.x=63
# Moving pipe at x=59, bottom_rect.x=59
# Moving pipe at x=55, bottom_rect.x=55
# Moving pipe at x=51, bottom_rect.x=51
# Moving pipe at x=47, bottom_rect.x=47
# Moving pipe at x=43, bottom_rect.x=43
# Episode 34/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=256, top_rect.y=118, bottom_rect.y=268
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Episode 35/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=259, top_rect.y=170, bottom_rect.y=320
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Episode 36/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=241, top_rect.y=232, bottom_rect.y=382
# Moving pipe at x=237, bottom_rect.x=237
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Episode 37/100, Total Reward: -10, Epsilon: 0.09910481551887473
# Created pipe at x=246, top_rect.y=152, bottom_rect.y=302
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# ...
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 96/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=238, top_rect.y=153, bottom_rect.y=303
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 97/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=271, top_rect.y=250, bottom_rect.y=400
# Moving pipe at x=267, bottom_rect.x=267
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 98/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=185, top_rect.y=187, bottom_rect.y=337
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 99/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=162, top_rect.y=233, bottom_rect.y=383
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 100/100, Total Reward: -1, Epsilon: 0.09910481551887473
# Created pipe at x=263, top_rect.y=250, bottom_rect.y=400
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Test Episode 1/10, Total Reward: -10
# Created pipe at x=146, top_rect.y=211, bottom_rect.y=361
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Test Episode 2/10, Total Reward: -1
# Created pipe at x=271, top_rect.y=196, bottom_rect.y=346
# Moving pipe at x=267, bottom_rect.x=267
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Test Episode 3/10, Total Reward: -10
# Created pipe at x=186, top_rect.y=254, bottom_rect.y=404
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Test Episode 4/10, Total Reward: -1
# Created pipe at x=157, top_rect.y=256, bottom_rect.y=406
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Test Episode 5/10, Total Reward: -1
# Created pipe at x=255, top_rect.y=121, bottom_rect.y=271
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Test Episode 6/10, Total Reward: -1
# Created pipe at x=149, top_rect.y=198, bottom_rect.y=348
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Test Episode 7/10, Total Reward: -1
# Created pipe at x=196, top_rect.y=231, bottom_rect.y=381
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Test Episode 8/10, Total Reward: -1
# Created pipe at x=151, top_rect.y=189, bottom_rect.y=339
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Moving pipe at x=99, bottom_rect.x=99
# Moving pipe at x=95, bottom_rect.x=95
# Moving pipe at x=91, bottom_rect.x=91
# Test Episode 9/10, Total Reward: -1
# Created pipe at x=271, top_rect.y=188, bottom_rect.y=338
# Moving pipe at x=267, bottom_rect.x=267
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Test Episode 10/10, Total Reward: -1

# %%
import matplotlib.pyplot as plt

# Call the test_agent function (after training is done)
test_rewards_2 = test_agent(env, trained_agent_exp_1, episodes=10)  # Replace `trained_agent` with your agent

# Plotting the learning curve for test rewards
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(test_rewards) + 1), test_rewards, label='Test Rewards', color='green')
plt.xlabel('Test Episode')
plt.ylabel('Total Reward')
plt.title('Test Learning Curve (Total Reward per Episode)')
plt.legend()
plt.show()
# Out:
# Created pipe at x=287, top_rect.y=169, bottom_rect.y=319
# Moving pipe at x=283, bottom_rect.x=283
# Moving pipe at x=279, bottom_rect.x=279
# Moving pipe at x=275, bottom_rect.x=275
# Moving pipe at x=271, bottom_rect.x=271
# Moving pipe at x=267, bottom_rect.x=267
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Test Episode 1/10, Total Reward: -10
# Created pipe at x=238, top_rect.y=211, bottom_rect.y=361
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Test Episode 2/10, Total Reward: -1
# Created pipe at x=205, top_rect.y=220, bottom_rect.y=370
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Test Episode 3/10, Total Reward: -10
# Created pipe at x=215, top_rect.y=145, bottom_rect.y=295
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Test Episode 4/10, Total Reward: -1
# Created pipe at x=272, top_rect.y=126, bottom_rect.y=276
# Moving pipe at x=268, bottom_rect.x=268
# Moving pipe at x=264, bottom_rect.x=264
# Moving pipe at x=260, bottom_rect.x=260
# Moving pipe at x=256, bottom_rect.x=256
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Test Episode 5/10, Total Reward: -1
# Created pipe at x=251, top_rect.y=113, bottom_rect.y=263
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Test Episode 6/10, Total Reward: -1
# Created pipe at x=249, top_rect.y=121, bottom_rect.y=271
# Moving pipe at x=245, bottom_rect.x=245
# Moving pipe at x=241, bottom_rect.x=241
# Moving pipe at x=237, bottom_rect.x=237
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Test Episode 7/10, Total Reward: -1
# Created pipe at x=144, top_rect.y=126, bottom_rect.y=276
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Moving pipe at x=76, bottom_rect.x=76
# Moving pipe at x=72, bottom_rect.x=72
# Moving pipe at x=68, bottom_rect.x=68
# Moving pipe at x=64, bottom_rect.x=64
# Moving pipe at x=60, bottom_rect.x=60
# Moving pipe at x=56, bottom_rect.x=56
# Moving pipe at x=52, bottom_rect.x=52
# Moving pipe at x=48, bottom_rect.x=48
# Moving pipe at x=44, bottom_rect.x=44
# Moving pipe at x=40, bottom_rect.x=40
# Moving pipe at x=36, bottom_rect.x=36
# Moving pipe at x=32, bottom_rect.x=32
# Moving pipe at x=28, bottom_rect.x=28
# Test Episode 8/10, Total Reward: -1
# Created pipe at x=283, top_rect.y=191, bottom_rect.y=341
# Moving pipe at x=279, bottom_rect.x=279
# Moving pipe at x=275, bottom_rect.x=275
# Moving pipe at x=271, bottom_rect.x=271
# Moving pipe at x=267, bottom_rect.x=267
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Test Episode 9/10, Total Reward: -1
# Created pipe at x=182, top_rect.y=245, bottom_rect.y=395
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Test Episode 10/10, Total Reward: -1

# %%
# Initialize the DQN agent (Experiment 2)
experiment_2_agent = DQNAgent(
    state_size=state_size,
    action_size=action_size,
    gamma=0.95,                      # Lower gamma for more immediate rewards
    epsilon=1.0,                     # Same as baseline
    epsilon_decay=0.995,             # Same as baseline
    epsilon_min=0.1,                 # Same as baseline
    batch_size=128,                  # Larger batch size
    memory_size=10000,               # Same as baseline
    learning_rate=0.001              # Same as baseline
)

# Train the agent with Experiment 2 hyperparameters
trained_agent_exp_2 = train_dqn(env, experiment_2_agent)

# Test the trained agent from Experiment 2
test_agent(env, trained_agent_exp_2)
# Out:
# Created pipe at x=164, top_rect.y=175, bottom_rect.y=325
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Episode 1/100, Total Reward: -1, Epsilon: 1.0
# Created pipe at x=151, top_rect.y=203, bottom_rect.y=353
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 2/100, Total Reward: -1, Epsilon: 1.0
# Created pipe at x=170, top_rect.y=236, bottom_rect.y=386
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 3/100, Total Reward: -1, Epsilon: 1.0
# Created pipe at x=147, top_rect.y=122, bottom_rect.y=272
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Moving pipe at x=99, bottom_rect.x=99
# Moving pipe at x=95, bottom_rect.x=95
# Moving pipe at x=91, bottom_rect.x=91
# Moving pipe at x=87, bottom_rect.x=87
# Moving pipe at x=83, bottom_rect.x=83
# Moving pipe at x=79, bottom_rect.x=79
# Moving pipe at x=75, bottom_rect.x=75
# Moving pipe at x=71, bottom_rect.x=71
# Moving pipe at x=67, bottom_rect.x=67
# Moving pipe at x=63, bottom_rect.x=63
# Moving pipe at x=59, bottom_rect.x=59
# Moving pipe at x=55, bottom_rect.x=55
# Moving pipe at x=51, bottom_rect.x=51
# Moving pipe at x=47, bottom_rect.x=47
# Moving pipe at x=43, bottom_rect.x=43
# Moving pipe at x=39, bottom_rect.x=39
# Moving pipe at x=35, bottom_rect.x=35
# Moving pipe at x=31, bottom_rect.x=31
# Episode 4/100, Total Reward: -10, Epsilon: 1.0
# Created pipe at x=186, top_rect.y=235, bottom_rect.y=385
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 5/100, Total Reward: -1, Epsilon: 1.0
# Created pipe at x=267, top_rect.y=120, bottom_rect.y=270
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 6/100, Total Reward: -1, Epsilon: 0.9511101304657719
# Created pipe at x=217, top_rect.y=101, bottom_rect.y=251
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Episode 7/100, Total Reward: -10, Epsilon: 0.8224322824348486
# Created pipe at x=259, top_rect.y=211, bottom_rect.y=361
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 8/100, Total Reward: -1, Epsilon: 0.6763948591909945
# Created pipe at x=190, top_rect.y=117, bottom_rect.y=267
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Moving pipe at x=98, bottom_rect.x=98
# Moving pipe at x=94, bottom_rect.x=94
# Moving pipe at x=90, bottom_rect.x=90
# Moving pipe at x=86, bottom_rect.x=86
# Moving pipe at x=82, bottom_rect.x=82
# Moving pipe at x=78, bottom_rect.x=78
# Moving pipe at x=74, bottom_rect.x=74
# Moving pipe at x=70, bottom_rect.x=70
# Moving pipe at x=66, bottom_rect.x=66
# Moving pipe at x=62, bottom_rect.x=62
# Episode 9/100, Total Reward: -1, Epsilon: 0.5761543988830038
# Created pipe at x=240, top_rect.y=189, bottom_rect.y=339
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Episode 10/100, Total Reward: -10, Epsilon: 0.4883155414435353
# Created pipe at x=200, top_rect.y=202, bottom_rect.y=352
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 11/100, Total Reward: -1, Epsilon: 0.43296668905325736
# Created pipe at x=201, top_rect.y=230, bottom_rect.y=380
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 12/100, Total Reward: -1, Epsilon: 0.38389143477919885
# Created pipe at x=150, top_rect.y=124, bottom_rect.y=274
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Moving pipe at x=98, bottom_rect.x=98
# Moving pipe at x=94, bottom_rect.x=94
# Moving pipe at x=90, bottom_rect.x=90
# Moving pipe at x=86, bottom_rect.x=86
# Moving pipe at x=82, bottom_rect.x=82
# Moving pipe at x=78, bottom_rect.x=78
# Moving pipe at x=74, bottom_rect.x=74
# Moving pipe at x=70, bottom_rect.x=70
# Moving pipe at x=66, bottom_rect.x=66
# Moving pipe at x=62, bottom_rect.x=62
# Moving pipe at x=58, bottom_rect.x=58
# Moving pipe at x=54, bottom_rect.x=54
# Moving pipe at x=50, bottom_rect.x=50
# Moving pipe at x=46, bottom_rect.x=46
# Moving pipe at x=42, bottom_rect.x=42
# Moving pipe at x=38, bottom_rect.x=38
# Moving pipe at x=34, bottom_rect.x=34
# Moving pipe at x=30, bottom_rect.x=30
# Moving pipe at x=26, bottom_rect.x=26
# Moving pipe at x=22, bottom_rect.x=22
# Moving pipe at x=18, bottom_rect.x=18
# Moving pipe at x=14, bottom_rect.x=14
# Moving pipe at x=10, bottom_rect.x=10
# Moving pipe at x=6, bottom_rect.x=6
# Moving pipe at x=2, bottom_rect.x=2
# Moving pipe at x=-2, bottom_rect.x=-2
# Moving pipe at x=-6, bottom_rect.x=-6
# Moving pipe at x=-10, bottom_rect.x=-10
# Moving pipe at x=-14, bottom_rect.x=-14
# Moving pipe at x=-18, bottom_rect.x=-18
# Moving pipe at x=-22, bottom_rect.x=-22
# Moving pipe at x=-26, bottom_rect.x=-26
# Moving pipe at x=-30, bottom_rect.x=-30
# Moving pipe at x=-34, bottom_rect.x=-34
# Moving pipe at x=-38, bottom_rect.x=-38
# Moving pipe at x=-42, bottom_rect.x=-42
# Moving pipe at x=-46, bottom_rect.x=-46
# Moving pipe at x=-50, bottom_rect.x=-50
# Moving pipe at x=-54, bottom_rect.x=-54
# Created pipe at x=194, top_rect.y=174, bottom_rect.y=324
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Episode 13/100, Total Reward: 0, Epsilon: 0.285607880564032
# Created pipe at x=237, top_rect.y=157, bottom_rect.y=307
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Episode 14/100, Total Reward: -1, Epsilon: 0.24206491716205145
# Created pipe at x=228, top_rect.y=126, bottom_rect.y=276
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 15/100, Total Reward: -1, Epsilon: 0.20722748400265262
# Created pipe at x=242, top_rect.y=244, bottom_rect.y=394
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 16/100, Total Reward: -1, Epsilon: 0.17388222158237718
# Created pipe at x=184, top_rect.y=128, bottom_rect.y=278
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Moving pipe at x=76, bottom_rect.x=76
# Moving pipe at x=72, bottom_rect.x=72
# Moving pipe at x=68, bottom_rect.x=68
# Moving pipe at x=64, bottom_rect.x=64
# Moving pipe at x=60, bottom_rect.x=60
# Moving pipe at x=56, bottom_rect.x=56
# Episode 17/100, Total Reward: -1, Epsilon: 0.14811319969530845
# Created pipe at x=178, top_rect.y=175, bottom_rect.y=325
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 18/100, Total Reward: -1, Epsilon: 0.1346580429260134
# Created pipe at x=274, top_rect.y=166, bottom_rect.y=316
# Moving pipe at x=270, bottom_rect.x=270
# Moving pipe at x=266, bottom_rect.x=266
# Moving pipe at x=262, bottom_rect.x=262
# Moving pipe at x=258, bottom_rect.x=258
# Moving pipe at x=254, bottom_rect.x=254
# Moving pipe at x=250, bottom_rect.x=250
# Moving pipe at x=246, bottom_rect.x=246
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Episode 19/100, Total Reward: -10, Epsilon: 0.10964241905397228
# Created pipe at x=214, top_rect.y=193, bottom_rect.y=343
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 20/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=209, top_rect.y=121, bottom_rect.y=271
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Episode 21/100, Total Reward: -10, Epsilon: 0.0996820918179746
# Created pipe at x=278, top_rect.y=169, bottom_rect.y=319
# Moving pipe at x=274, bottom_rect.x=274
# Moving pipe at x=270, bottom_rect.x=270
# Moving pipe at x=266, bottom_rect.x=266
# Moving pipe at x=262, bottom_rect.x=262
# Moving pipe at x=258, bottom_rect.x=258
# Moving pipe at x=254, bottom_rect.x=254
# Moving pipe at x=250, bottom_rect.x=250
# Moving pipe at x=246, bottom_rect.x=246
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Episode 22/100, Total Reward: -10, Epsilon: 0.0996820918179746
# Created pipe at x=274, top_rect.y=259, bottom_rect.y=409
# Moving pipe at x=270, bottom_rect.x=270
# Moving pipe at x=266, bottom_rect.x=266
# Moving pipe at x=262, bottom_rect.x=262
# Moving pipe at x=258, bottom_rect.x=258
# Moving pipe at x=254, bottom_rect.x=254
# Moving pipe at x=250, bottom_rect.x=250
# Moving pipe at x=246, bottom_rect.x=246
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 23/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=148, top_rect.y=243, bottom_rect.y=393
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 24/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=187, top_rect.y=160, bottom_rect.y=310
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 25/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=255, top_rect.y=114, bottom_rect.y=264
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 26/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=260, top_rect.y=217, bottom_rect.y=367
# Moving pipe at x=256, bottom_rect.x=256
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 27/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=159, top_rect.y=155, bottom_rect.y=305
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Moving pipe at x=99, bottom_rect.x=99
# Moving pipe at x=95, bottom_rect.x=95
# Moving pipe at x=91, bottom_rect.x=91
# Moving pipe at x=87, bottom_rect.x=87
# Moving pipe at x=83, bottom_rect.x=83
# Moving pipe at x=79, bottom_rect.x=79
# Moving pipe at x=75, bottom_rect.x=75
# Moving pipe at x=71, bottom_rect.x=71
# Moving pipe at x=67, bottom_rect.x=67
# Episode 28/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=178, top_rect.y=173, bottom_rect.y=323
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Episode 29/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=184, top_rect.y=235, bottom_rect.y=385
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 30/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=280, top_rect.y=184, bottom_rect.y=334
# Moving pipe at x=276, bottom_rect.x=276
# Moving pipe at x=272, bottom_rect.x=272
# Moving pipe at x=268, bottom_rect.x=268
# Moving pipe at x=264, bottom_rect.x=264
# Moving pipe at x=260, bottom_rect.x=260
# Moving pipe at x=256, bottom_rect.x=256
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 31/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=271, top_rect.y=212, bottom_rect.y=362
# Moving pipe at x=267, bottom_rect.x=267
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Episode 32/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=165, top_rect.y=118, bottom_rect.y=268
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Moving pipe at x=77, bottom_rect.x=77
# Moving pipe at x=73, bottom_rect.x=73
# Moving pipe at x=69, bottom_rect.x=69
# Moving pipe at x=65, bottom_rect.x=65
# Moving pipe at x=61, bottom_rect.x=61
# Moving pipe at x=57, bottom_rect.x=57
# Moving pipe at x=53, bottom_rect.x=53
# Moving pipe at x=49, bottom_rect.x=49
# Moving pipe at x=45, bottom_rect.x=45
# Moving pipe at x=41, bottom_rect.x=41
# Moving pipe at x=37, bottom_rect.x=37
# Moving pipe at x=33, bottom_rect.x=33
# Moving pipe at x=29, bottom_rect.x=29
# Moving pipe at x=25, bottom_rect.x=25
# Episode 33/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=192, top_rect.y=141, bottom_rect.y=291
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Episode 34/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=232, top_rect.y=203, bottom_rect.y=353
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Episode 35/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=144, top_rect.y=135, bottom_rect.y=285
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Moving pipe at x=76, bottom_rect.x=76
# Moving pipe at x=72, bottom_rect.x=72
# Moving pipe at x=68, bottom_rect.x=68
# Moving pipe at x=64, bottom_rect.x=64
# Moving pipe at x=60, bottom_rect.x=60
# Moving pipe at x=56, bottom_rect.x=56
# Moving pipe at x=52, bottom_rect.x=52
# Moving pipe at x=48, bottom_rect.x=48
# Moving pipe at x=44, bottom_rect.x=44
# Moving pipe at x=40, bottom_rect.x=40
# Moving pipe at x=36, bottom_rect.x=36
# Moving pipe at x=32, bottom_rect.x=32
# Episode 36/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=153, top_rect.y=170, bottom_rect.y=320
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Moving pipe at x=77, bottom_rect.x=77
# Moving pipe at x=73, bottom_rect.x=73
# Moving pipe at x=69, bottom_rect.x=69
# Moving pipe at x=65, bottom_rect.x=65
# Moving pipe at x=61, bottom_rect.x=61
# Moving pipe at x=57, bottom_rect.x=57
# Moving pipe at x=53, bottom_rect.x=53
# Episode 37/100, Total Reward: -1, Epsilon: 0.0996820918179746
# Created pipe at x=171, top_rect.y=185, bottom_rect.y=335
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# ...
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Test Episode 1/10, Total Reward: -10
# Created pipe at x=208, top_rect.y=105, bottom_rect.y=255
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Moving pipe at x=76, bottom_rect.x=76
# Moving pipe at x=72, bottom_rect.x=72
# Moving pipe at x=68, bottom_rect.x=68
# Moving pipe at x=64, bottom_rect.x=64
# Moving pipe at x=60, bottom_rect.x=60
# Moving pipe at x=56, bottom_rect.x=56
# Moving pipe at x=52, bottom_rect.x=52
# Moving pipe at x=48, bottom_rect.x=48
# Moving pipe at x=44, bottom_rect.x=44
# Moving pipe at x=40, bottom_rect.x=40
# Moving pipe at x=36, bottom_rect.x=36
# Moving pipe at x=32, bottom_rect.x=32
# Moving pipe at x=28, bottom_rect.x=28
# Moving pipe at x=24, bottom_rect.x=24
# Moving pipe at x=20, bottom_rect.x=20
# Moving pipe at x=16, bottom_rect.x=16
# Moving pipe at x=12, bottom_rect.x=12
# Moving pipe at x=8, bottom_rect.x=8
# Moving pipe at x=4, bottom_rect.x=4
# Moving pipe at x=0, bottom_rect.x=0
# Moving pipe at x=-4, bottom_rect.x=-4
# Moving pipe at x=-8, bottom_rect.x=-8
# Moving pipe at x=-12, bottom_rect.x=-12
# Moving pipe at x=-16, bottom_rect.x=-16
# Moving pipe at x=-20, bottom_rect.x=-20
# Moving pipe at x=-24, bottom_rect.x=-24
# Moving pipe at x=-28, bottom_rect.x=-28
# Moving pipe at x=-32, bottom_rect.x=-32
# Moving pipe at x=-36, bottom_rect.x=-36
# Moving pipe at x=-40, bottom_rect.x=-40
# Moving pipe at x=-44, bottom_rect.x=-44
# Moving pipe at x=-48, bottom_rect.x=-48
# Moving pipe at x=-52, bottom_rect.x=-52
# Created pipe at x=172, top_rect.y=105, bottom_rect.y=255
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Test Episode 2/10, Total Reward: 0
# Created pipe at x=145, top_rect.y=123, bottom_rect.y=273
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Moving pipe at x=101, bottom_rect.x=101
# Moving pipe at x=97, bottom_rect.x=97
# Moving pipe at x=93, bottom_rect.x=93
# Moving pipe at x=89, bottom_rect.x=89
# Moving pipe at x=85, bottom_rect.x=85
# Moving pipe at x=81, bottom_rect.x=81
# Moving pipe at x=77, bottom_rect.x=77
# Moving pipe at x=73, bottom_rect.x=73
# Moving pipe at x=69, bottom_rect.x=69
# Moving pipe at x=65, bottom_rect.x=65
# Moving pipe at x=61, bottom_rect.x=61
# Moving pipe at x=57, bottom_rect.x=57
# Moving pipe at x=53, bottom_rect.x=53
# Moving pipe at x=49, bottom_rect.x=49
# Moving pipe at x=45, bottom_rect.x=45
# Moving pipe at x=41, bottom_rect.x=41
# Moving pipe at x=37, bottom_rect.x=37
# Moving pipe at x=33, bottom_rect.x=33
# Moving pipe at x=29, bottom_rect.x=29
# Moving pipe at x=25, bottom_rect.x=25
# Moving pipe at x=21, bottom_rect.x=21
# Moving pipe at x=17, bottom_rect.x=17
# Moving pipe at x=13, bottom_rect.x=13
# Moving pipe at x=9, bottom_rect.x=9
# Moving pipe at x=5, bottom_rect.x=5
# Moving pipe at x=1, bottom_rect.x=1
# Moving pipe at x=-3, bottom_rect.x=-3
# Moving pipe at x=-7, bottom_rect.x=-7
# Moving pipe at x=-11, bottom_rect.x=-11
# Moving pipe at x=-15, bottom_rect.x=-15
# Moving pipe at x=-19, bottom_rect.x=-19
# Moving pipe at x=-23, bottom_rect.x=-23
# Moving pipe at x=-27, bottom_rect.x=-27
# Moving pipe at x=-31, bottom_rect.x=-31
# Moving pipe at x=-35, bottom_rect.x=-35
# Moving pipe at x=-39, bottom_rect.x=-39
# Moving pipe at x=-43, bottom_rect.x=-43
# Moving pipe at x=-47, bottom_rect.x=-47
# Moving pipe at x=-51, bottom_rect.x=-51
# Created pipe at x=237, top_rect.y=228, bottom_rect.y=378
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Test Episode 3/10, Total Reward: 0
# Created pipe at x=208, top_rect.y=245, bottom_rect.y=395
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Test Episode 4/10, Total Reward: -1
# Created pipe at x=187, top_rect.y=162, bottom_rect.y=312
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Moving pipe at x=99, bottom_rect.x=99
# Moving pipe at x=95, bottom_rect.x=95
# Moving pipe at x=91, bottom_rect.x=91
# Moving pipe at x=87, bottom_rect.x=87
# Moving pipe at x=83, bottom_rect.x=83
# Moving pipe at x=79, bottom_rect.x=79
# Moving pipe at x=75, bottom_rect.x=75
# Moving pipe at x=71, bottom_rect.x=71
# Moving pipe at x=67, bottom_rect.x=67
# Moving pipe at x=63, bottom_rect.x=63
# Moving pipe at x=59, bottom_rect.x=59
# Moving pipe at x=55, bottom_rect.x=55
# Moving pipe at x=51, bottom_rect.x=51
# Moving pipe at x=47, bottom_rect.x=47
# Moving pipe at x=43, bottom_rect.x=43
# Moving pipe at x=39, bottom_rect.x=39
# Moving pipe at x=35, bottom_rect.x=35
# Test Episode 5/10, Total Reward: -1
# Created pipe at x=273, top_rect.y=229, bottom_rect.y=379
# Moving pipe at x=269, bottom_rect.x=269
# Moving pipe at x=265, bottom_rect.x=265
# Moving pipe at x=261, bottom_rect.x=261
# Moving pipe at x=257, bottom_rect.x=257
# Moving pipe at x=253, bottom_rect.x=253
# Moving pipe at x=249, bottom_rect.x=249
# Moving pipe at x=245, bottom_rect.x=245
# Moving pipe at x=241, bottom_rect.x=241
# Moving pipe at x=237, bottom_rect.x=237
# Moving pipe at x=233, bottom_rect.x=233
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Test Episode 6/10, Total Reward: -1
# Created pipe at x=216, top_rect.y=148, bottom_rect.y=298
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Test Episode 7/10, Total Reward: -10
# Created pipe at x=218, top_rect.y=147, bottom_rect.y=297
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Moving pipe at x=98, bottom_rect.x=98
# Moving pipe at x=94, bottom_rect.x=94
# Moving pipe at x=90, bottom_rect.x=90
# Moving pipe at x=86, bottom_rect.x=86
# Moving pipe at x=82, bottom_rect.x=82
# Moving pipe at x=78, bottom_rect.x=78
# Moving pipe at x=74, bottom_rect.x=74
# Moving pipe at x=70, bottom_rect.x=70
# Moving pipe at x=66, bottom_rect.x=66
# Moving pipe at x=62, bottom_rect.x=62
# Moving pipe at x=58, bottom_rect.x=58
# Moving pipe at x=54, bottom_rect.x=54
# Moving pipe at x=50, bottom_rect.x=50
# Moving pipe at x=46, bottom_rect.x=46
# Moving pipe at x=42, bottom_rect.x=42
# Test Episode 8/10, Total Reward: -1
# Created pipe at x=218, top_rect.y=191, bottom_rect.y=341
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Test Episode 9/10, Total Reward: -10
# Created pipe at x=147, top_rect.y=160, bottom_rect.y=310
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Moving pipe at x=99, bottom_rect.x=99
# Moving pipe at x=95, bottom_rect.x=95
# Moving pipe at x=91, bottom_rect.x=91
# Moving pipe at x=87, bottom_rect.x=87
# Moving pipe at x=83, bottom_rect.x=83
# Moving pipe at x=79, bottom_rect.x=79
# Moving pipe at x=75, bottom_rect.x=75
# Moving pipe at x=71, bottom_rect.x=71
# Moving pipe at x=67, bottom_rect.x=67
# Moving pipe at x=63, bottom_rect.x=63
# Moving pipe at x=59, bottom_rect.x=59
# Moving pipe at x=55, bottom_rect.x=55
# Moving pipe at x=51, bottom_rect.x=51
# Moving pipe at x=47, bottom_rect.x=47
# Moving pipe at x=43, bottom_rect.x=43
# Test Episode 10/10, Total Reward: -1

# %%
import matplotlib.pyplot as plt

# Call the test_agent function (after training is done)
test_rewards_3 = test_agent(env, trained_agent_exp_2, episodes=10)  # Replace `trained_agent` with your agent

# Plotting the learning curve for test rewards
plt.figure(figsize=(10, 6))
plt.plot(range(1, len(test_rewards) + 1), test_rewards, label='Test Rewards', color='green')
plt.xlabel('Test Episode')
plt.ylabel('Total Reward')
plt.title('Test Learning Curve (Total Reward per Episode)')
plt.legend()
plt.show()
# Out:
# Created pipe at x=164, top_rect.y=115, bottom_rect.y=265
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Moving pipe at x=76, bottom_rect.x=76
# Moving pipe at x=72, bottom_rect.x=72
# Moving pipe at x=68, bottom_rect.x=68
# Moving pipe at x=64, bottom_rect.x=64
# Moving pipe at x=60, bottom_rect.x=60
# Moving pipe at x=56, bottom_rect.x=56
# Moving pipe at x=52, bottom_rect.x=52
# Moving pipe at x=48, bottom_rect.x=48
# Moving pipe at x=44, bottom_rect.x=44
# Moving pipe at x=40, bottom_rect.x=40
# Moving pipe at x=36, bottom_rect.x=36
# Test Episode 1/10, Total Reward: -1
# Created pipe at x=222, top_rect.y=155, bottom_rect.y=305
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Test Episode 2/10, Total Reward: -1
# Created pipe at x=266, top_rect.y=100, bottom_rect.y=250
# Moving pipe at x=262, bottom_rect.x=262
# Moving pipe at x=258, bottom_rect.x=258
# Moving pipe at x=254, bottom_rect.x=254
# Moving pipe at x=250, bottom_rect.x=250
# Moving pipe at x=246, bottom_rect.x=246
# Moving pipe at x=242, bottom_rect.x=242
# Moving pipe at x=238, bottom_rect.x=238
# Moving pipe at x=234, bottom_rect.x=234
# Moving pipe at x=230, bottom_rect.x=230
# Moving pipe at x=226, bottom_rect.x=226
# Moving pipe at x=222, bottom_rect.x=222
# Moving pipe at x=218, bottom_rect.x=218
# Moving pipe at x=214, bottom_rect.x=214
# Moving pipe at x=210, bottom_rect.x=210
# Moving pipe at x=206, bottom_rect.x=206
# Moving pipe at x=202, bottom_rect.x=202
# Moving pipe at x=198, bottom_rect.x=198
# Moving pipe at x=194, bottom_rect.x=194
# Moving pipe at x=190, bottom_rect.x=190
# Moving pipe at x=186, bottom_rect.x=186
# Moving pipe at x=182, bottom_rect.x=182
# Moving pipe at x=178, bottom_rect.x=178
# Moving pipe at x=174, bottom_rect.x=174
# Moving pipe at x=170, bottom_rect.x=170
# Moving pipe at x=166, bottom_rect.x=166
# Moving pipe at x=162, bottom_rect.x=162
# Moving pipe at x=158, bottom_rect.x=158
# Moving pipe at x=154, bottom_rect.x=154
# Moving pipe at x=150, bottom_rect.x=150
# Moving pipe at x=146, bottom_rect.x=146
# Moving pipe at x=142, bottom_rect.x=142
# Moving pipe at x=138, bottom_rect.x=138
# Moving pipe at x=134, bottom_rect.x=134
# Moving pipe at x=130, bottom_rect.x=130
# Moving pipe at x=126, bottom_rect.x=126
# Moving pipe at x=122, bottom_rect.x=122
# Moving pipe at x=118, bottom_rect.x=118
# Moving pipe at x=114, bottom_rect.x=114
# Moving pipe at x=110, bottom_rect.x=110
# Moving pipe at x=106, bottom_rect.x=106
# Moving pipe at x=102, bottom_rect.x=102
# Moving pipe at x=98, bottom_rect.x=98
# Moving pipe at x=94, bottom_rect.x=94
# Test Episode 3/10, Total Reward: -1
# Created pipe at x=225, top_rect.y=241, bottom_rect.y=391
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Moving pipe at x=141, bottom_rect.x=141
# Moving pipe at x=137, bottom_rect.x=137
# Moving pipe at x=133, bottom_rect.x=133
# Moving pipe at x=129, bottom_rect.x=129
# Moving pipe at x=125, bottom_rect.x=125
# Moving pipe at x=121, bottom_rect.x=121
# Moving pipe at x=117, bottom_rect.x=117
# Moving pipe at x=113, bottom_rect.x=113
# Moving pipe at x=109, bottom_rect.x=109
# Moving pipe at x=105, bottom_rect.x=105
# Test Episode 4/10, Total Reward: -1
# Created pipe at x=267, top_rect.y=170, bottom_rect.y=320
# Moving pipe at x=263, bottom_rect.x=263
# Moving pipe at x=259, bottom_rect.x=259
# Moving pipe at x=255, bottom_rect.x=255
# Moving pipe at x=251, bottom_rect.x=251
# Moving pipe at x=247, bottom_rect.x=247
# Moving pipe at x=243, bottom_rect.x=243
# Moving pipe at x=239, bottom_rect.x=239
# Moving pipe at x=235, bottom_rect.x=235
# Moving pipe at x=231, bottom_rect.x=231
# Moving pipe at x=227, bottom_rect.x=227
# Moving pipe at x=223, bottom_rect.x=223
# Moving pipe at x=219, bottom_rect.x=219
# Moving pipe at x=215, bottom_rect.x=215
# Moving pipe at x=211, bottom_rect.x=211
# Moving pipe at x=207, bottom_rect.x=207
# Moving pipe at x=203, bottom_rect.x=203
# Moving pipe at x=199, bottom_rect.x=199
# Moving pipe at x=195, bottom_rect.x=195
# Moving pipe at x=191, bottom_rect.x=191
# Moving pipe at x=187, bottom_rect.x=187
# Moving pipe at x=183, bottom_rect.x=183
# Moving pipe at x=179, bottom_rect.x=179
# Moving pipe at x=175, bottom_rect.x=175
# Moving pipe at x=171, bottom_rect.x=171
# Moving pipe at x=167, bottom_rect.x=167
# Moving pipe at x=163, bottom_rect.x=163
# Moving pipe at x=159, bottom_rect.x=159
# Moving pipe at x=155, bottom_rect.x=155
# Moving pipe at x=151, bottom_rect.x=151
# Moving pipe at x=147, bottom_rect.x=147
# Moving pipe at x=143, bottom_rect.x=143
# Moving pipe at x=139, bottom_rect.x=139
# Moving pipe at x=135, bottom_rect.x=135
# Moving pipe at x=131, bottom_rect.x=131
# Moving pipe at x=127, bottom_rect.x=127
# Moving pipe at x=123, bottom_rect.x=123
# Moving pipe at x=119, bottom_rect.x=119
# Moving pipe at x=115, bottom_rect.x=115
# Moving pipe at x=111, bottom_rect.x=111
# Moving pipe at x=107, bottom_rect.x=107
# Moving pipe at x=103, bottom_rect.x=103
# Test Episode 5/10, Total Reward: -1
# Created pipe at x=144, top_rect.y=176, bottom_rect.y=326
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Moving pipe at x=76, bottom_rect.x=76
# Moving pipe at x=72, bottom_rect.x=72
# Moving pipe at x=68, bottom_rect.x=68
# Moving pipe at x=64, bottom_rect.x=64
# Moving pipe at x=60, bottom_rect.x=60
# Test Episode 6/10, Total Reward: -1
# Created pipe at x=272, top_rect.y=228, bottom_rect.y=378
# Moving pipe at x=268, bottom_rect.x=268
# Moving pipe at x=264, bottom_rect.x=264
# Moving pipe at x=260, bottom_rect.x=260
# Moving pipe at x=256, bottom_rect.x=256
# Moving pipe at x=252, bottom_rect.x=252
# Moving pipe at x=248, bottom_rect.x=248
# Moving pipe at x=244, bottom_rect.x=244
# Moving pipe at x=240, bottom_rect.x=240
# Moving pipe at x=236, bottom_rect.x=236
# Moving pipe at x=232, bottom_rect.x=232
# Moving pipe at x=228, bottom_rect.x=228
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Test Episode 7/10, Total Reward: -10
# Created pipe at x=204, top_rect.y=161, bottom_rect.y=311
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Test Episode 8/10, Total Reward: -1
# Created pipe at x=233, top_rect.y=120, bottom_rect.y=270
# Moving pipe at x=229, bottom_rect.x=229
# Moving pipe at x=225, bottom_rect.x=225
# Moving pipe at x=221, bottom_rect.x=221
# Moving pipe at x=217, bottom_rect.x=217
# Moving pipe at x=213, bottom_rect.x=213
# Moving pipe at x=209, bottom_rect.x=209
# Moving pipe at x=205, bottom_rect.x=205
# Moving pipe at x=201, bottom_rect.x=201
# Moving pipe at x=197, bottom_rect.x=197
# Moving pipe at x=193, bottom_rect.x=193
# Moving pipe at x=189, bottom_rect.x=189
# Moving pipe at x=185, bottom_rect.x=185
# Moving pipe at x=181, bottom_rect.x=181
# Moving pipe at x=177, bottom_rect.x=177
# Moving pipe at x=173, bottom_rect.x=173
# Moving pipe at x=169, bottom_rect.x=169
# Moving pipe at x=165, bottom_rect.x=165
# Moving pipe at x=161, bottom_rect.x=161
# Moving pipe at x=157, bottom_rect.x=157
# Moving pipe at x=153, bottom_rect.x=153
# Moving pipe at x=149, bottom_rect.x=149
# Moving pipe at x=145, bottom_rect.x=145
# Test Episode 9/10, Total Reward: -10
# Created pipe at x=228, top_rect.y=120, bottom_rect.y=270
# Moving pipe at x=224, bottom_rect.x=224
# Moving pipe at x=220, bottom_rect.x=220
# Moving pipe at x=216, bottom_rect.x=216
# Moving pipe at x=212, bottom_rect.x=212
# Moving pipe at x=208, bottom_rect.x=208
# Moving pipe at x=204, bottom_rect.x=204
# Moving pipe at x=200, bottom_rect.x=200
# Moving pipe at x=196, bottom_rect.x=196
# Moving pipe at x=192, bottom_rect.x=192
# Moving pipe at x=188, bottom_rect.x=188
# Moving pipe at x=184, bottom_rect.x=184
# Moving pipe at x=180, bottom_rect.x=180
# Moving pipe at x=176, bottom_rect.x=176
# Moving pipe at x=172, bottom_rect.x=172
# Moving pipe at x=168, bottom_rect.x=168
# Moving pipe at x=164, bottom_rect.x=164
# Moving pipe at x=160, bottom_rect.x=160
# Moving pipe at x=156, bottom_rect.x=156
# Moving pipe at x=152, bottom_rect.x=152
# Moving pipe at x=148, bottom_rect.x=148
# Moving pipe at x=144, bottom_rect.x=144
# Moving pipe at x=140, bottom_rect.x=140
# Moving pipe at x=136, bottom_rect.x=136
# Moving pipe at x=132, bottom_rect.x=132
# Moving pipe at x=128, bottom_rect.x=128
# Moving pipe at x=124, bottom_rect.x=124
# Moving pipe at x=120, bottom_rect.x=120
# Moving pipe at x=116, bottom_rect.x=116
# Moving pipe at x=112, bottom_rect.x=112
# Moving pipe at x=108, bottom_rect.x=108
# Moving pipe at x=104, bottom_rect.x=104
# Moving pipe at x=100, bottom_rect.x=100
# Moving pipe at x=96, bottom_rect.x=96
# Moving pipe at x=92, bottom_rect.x=92
# Moving pipe at x=88, bottom_rect.x=88
# Moving pipe at x=84, bottom_rect.x=84
# Moving pipe at x=80, bottom_rect.x=80
# Moving pipe at x=76, bottom_rect.x=76
# Moving pipe at x=72, bottom_rect.x=72
# Moving pipe at x=68, bottom_rect.x=68
# Moving pipe at x=64, bottom_rect.x=64
# Moving pipe at x=60, bottom_rect.x=60
# Moving pipe at x=56, bottom_rect.x=56
# Moving pipe at x=52, bottom_rect.x=52
# Moving pipe at x=48, bottom_rect.x=48
# Moving pipe at x=44, bottom_rect.x=44
# Moving pipe at x=40, bottom_rect.x=40
# Test Episode 10/10, Total Reward: -1

# %%
import matplotlib.pyplot as plt

# Assuming these variables already contain the test rewards for each experiment
# baseline_test_rewards, test_rewards_2, test_rewards_3

# Plotting the learning curve for all three experiments
plt.figure(figsize=(10, 6))

# Plot for Baseline
plt.plot(range(1, len(baseline_test_rewards) + 1), baseline_test_rewards, label='Baseline', color='blue')

# Plot for Experiment 1 (test_rewards_2)
plt.plot(range(1, len(test_rewards_2) + 1), test_rewards_2, label='Experiment 1', color='green')

# Plot for Experiment 2 (test_rewards_3)
plt.plot(range(1, len(test_rewards_3) + 1), test_rewards_3, label='Experiment 2', color='red')

# Adding labels and title
plt.xlabel('Test Episode')
plt.ylabel('Total Reward')
plt.title('Learning Curve Comparison (Total Reward per Test Episode)')
plt.legend()  # To show the label of each curve
plt.grid(True)  # Adding grid for better readability

# Show the plot
plt.show()

# %% [markdown]
# In this plot, I've compared the learning curves of three different agents: Baseline, Experiment 1, and Experiment 2. The x-axis represents the test episodes (10 total), and the y-axis shows the total reward achieved by the agent during each test episode. Positive rewards indicate the agent is performing well, while negative rewards suggest poor performance.
#
# Observations:
# Baseline (Blue line): The baseline agent’s performance shows a sharp increase in reward by the 10th episode. It starts off with fluctuating performance, but by the end, the agent demonstrates significant improvement, with a large jump in reward in Episode 10. The training for the baseline agent took around 500 minutes, which is the shortest time among all three experiments.
#
# Experiment 1 (Green line): The performance in Experiment 1 is a bit more consistent but less impressive than the baseline. While the agent does show some improvement, the rewards remain relatively stable with minor ups and downs. Experiment 1 took about 558 minutes of training, which was a bit longer than the baseline, but not by a large margin.
#
# Experiment 2 (Red line): The performance of Experiment 2 fluctuates the most across episodes, with a mix of positive and negative rewards. The agent struggles in some episodes, resulting in large drops in rewards. It did show some positive rewards towards the end, but it didn’t manage to stabilize as well as the baseline. Experiment 2 took the longest time to train—around 1198 minutes. The longer training time didn’t seem to lead to significantly better performance, which might indicate that further adjustments to the agent's hyperparameters or exploration strategy are needed.
#
# Time Spent:
# The Baseline took 500 minutes to train and produced relatively decent results, showing the most improvement in the final episodes.
#
# Experiment 1 took 558 minutes, slightly longer than the baseline, but its performance wasn’t notably better.
#
# Experiment 2 was by far the longest at 1198 minutes, but its performance did not justify the extra time spent on training.
#
# Conclusion:
# Despite the longer training times for Experiment 1 and 2, none of the experiments significantly outperformed the baseline in terms of reward. The baseline agent demonstrated improvement toward the final episodes, while both Experiment 1 and 2 had more inconsistent results, with some episodes showing negative rewards. This comparison suggests that the additional training time for Experiment 2 did not result in proportional improvements in performance.
